# %%
############ LIBRARIES (updated) ###############

from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
import os
import csv
import tsfresh
from tsfresh import extract_features
from tsfresh.utilities.dataframe_functions import impute
from tsfresh import extract_relevant_features
from tsfresh import select_features


# Regressors
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from xgboost.sklearn import XGBRegressor 
from sklearn.ensemble import RandomForestRegressor
from sklearn.neural_network import MLPRegressor
import lightgbm as lgb

import warnings
from warnings import simplefilter
warnings.filterwarnings("ignore", category=RuntimeWarning)
simplefilter(action='ignore', category=FutureWarning)

# Evaluation metrics
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import mean_absolute_percentage_error as mape

# %matplotlib inline

epslon = 0.00005

def pbe(y_true, y_pred):
  if np.sum(y_true)!=0:
    return 100*(np.sum(y_pred - y_true)/np.sum(y_true))
  else:
   return 100*(np.sum(y_pred - y_true)/(np.sum(y_true)+ epslon))  

def pocid(y_true, y_pred):
  n = len(y_true)
  D = [1 if (y_pred[i] - y_pred[i-1]) * (y_true[i] - y_true[i-1]) > 0 else 0 for i in range(1, n)]
  POCID = 100 * np.sum(D) / (n-1)
  return POCID

#função para normalização
def znorm(x):
  if np.std(x)!=0:
    x_znorm = (x - np.mean(x)) / np.std(x)
  else:
    x_znorm = (x - np.mean(x)) / (np.std(x) + epslon) 
   
  return x_znorm

#função para desnormatização
def znorm_reverse(x, mean_x, std_x):
  x_denormalized = (np.array(x) * std_x) + mean_x
  return x_denormalized

def get_stats_norm(series, horizon, window):
  last_subsequence = series[-(horizon+window):-horizon].values
  last_mean = np.mean(last_subsequence)
  last_std = np.std(last_subsequence)
  return last_mean, last_std

# Em geral, considera-se um tamanho de janela capaz de capturar um ciclo dos dados
# Por exemplo, 12 observações no caso dos dados com frequência mensal
def rolling_window(series, window):
  data = []
  for i in range(len(series)-window):
    example = znorm(np.array(series[i:i+window+1]))
    data.append(example)
  df = pd.DataFrame(data)
  return df

def rolling_window_real(series, window):
  data = []
  for i in range(len(series)-window):
    # example = znorm(np.array(series[i:i+window+1]))
    example = np.array(series[i:i+window+1])
    data.append(example)
  df = pd.DataFrame(data)
  return df

# Para predição de vendas por UF (mensal), será considerado horizon = 12
# Para predição de vendas por município (anual), será considerado horizon = 1
def train_test_split(data, horizon):
  X = data.iloc[:,:-1] # features
  y = data.iloc[:,-1] # target

  X_train = X[:-horizon] # features train
  X_test =  X[-horizon:] # features test

  y_train = y[:-horizon] # target train
  y_test = y[-horizon:] # target test
  return X_train, X_test, y_train, y_test

def recursive_multistep_forecasting(X_test, model, horizon):
  # example é composto pelas últimas observações vistas
  # na prática, é o pbeprimeiro exemplo do conjunto de teste
  example = X_test.iloc[0].values.reshape(1,-1)

  preds = []
  for i in range(horizon):
    pred = model.predict(example)[0]
    preds.append(pred)

    # Descartar o valor da primeira posição do vetor de características
    example = example[:,1:]

    # Adicionar o valor predito na última posição do vetor de características
    example = np.append(example, pred)
    example = example.reshape(1,-1)
  return preds


def rolling_window_TsFresh(series, window):
    concatenated_results = None  # Initialize as None
    for i in range(len(series) - window):  # Adjusted range to include the last window
        target_feat = series[i:i+window]
        target_feat2 = pd.DataFrame(target_feat)

        target_feat2.insert(0, 'id', 'D1')  # Example: inserting 'D1' as id

        result = extract_features(target_feat2, column_id="id")

        result_values = result.values
        
        if concatenated_results is None:
            concatenated_results = result_values
        else:
            concatenated_results = np.concatenate((concatenated_results, result_values), axis=0)
    
    return concatenated_results
# Out:
# /usr/local/lib/python3.12/dist-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
#### LEITURA DOS DADOS ####

def extract_estado(file_name):
    # Split the file name by underscores
    parts = file_name.split('_')
    # Extract the name between underscores
    estado = parts[1]
    return estado

def read_csv_files(folder_path):
    estados = []
    # List all files in the folder
    files = os.listdir(folder_path)
    # Iterate through each file
    for file_name in files:
        # Check if it's a CSV file
        if file_name.endswith('.csv'):
            file_path = os.path.join(folder_path, file_name)
            # Open the CSV file and read the data
            with open(file_path, 'r', newline='') as csvfile:
                reader = csv.reader(csvfile)
                # Assuming the first row contains headers
                headers = next(reader)
                # Extract estado from file name and append to estados list
                estado = extract_estado(file_name)
                estados.append(estado)
                estados.sort()
    return estados

# %%
############## TsFresh AUTO ##############

import pickle

horizon = 12
window = 12
features = 'TsFresh'

products = sorted([name for name in os.listdir('./') if os.path.isdir(os.path.join('./', name))])
 
for product in products:
    folder_path = f'./{product}/'
    # Read the CSV files and extract estado names
    estados = read_csv_files(folder_path)
    
    for estado in estados:

        # carregamento do arquivo

        df = pd.read_csv(f"./{product}/mensal_{estado}_{product}.csv", header=0, sep=";")
        series = df['m3']

        TimeStamp = df['timestamp'].tail(398) ## add
        TimeStamp.reset_index(drop=True, inplace=True) ## add

        df_feat = rolling_window_TsFresh(series, window) ## add
        df_feat2 = pd.DataFrame(df_feat)
        df_feat2 = df_feat2.fillna(0) ## add
        # df_feat2.replace([np.inf, -np.inf], 0, inplace=True)
        # df_feat3 = df_feat2.loc[:, df_feat2.nunique() > 1]


        ## Somente Features - Normalizadas ##
        # df_feat_norm = df_feat2.apply(znorm, axis=1)

        # targets = rolling_window(series, window)
        # last_column_target = targets.iloc[:, -1]

        # df_feat_norm['y'] = last_column_target
 
        # first_column = Catch22_filled.pop('timestamp') 
        df_feat2.insert(0, 'timestamp', TimeStamp) ## add

        folder_name = f'../SALVAS/{product}/'
        if not os.path.exists(folder_name):
            os.makedirs(folder_name)
        
        df_feat2.to_csv(f'{folder_name}/FEAT_TsFresh_{product}_{window}_{estado}.csv', index=False)

        # ##################################################################################
        # # Divisão dos dados em treino/teste considerando o horizonte de predição de 12 meses
        # X_train, X_test, y_train, y_test = train_test_split(Catch22_filled, horizon)

        # #######################  lgb  #######################
        # num_round = 100

        # # Convert data to LightGBM dataset format
        # train_data = lgb.Dataset(X_train, label=y_train)
        # test_data = lgb.Dataset(X_test, label=y_test)

        # ############## Regressores ##################
        # # regr1 = LinearRegression()
        # regr2 = KNeighborsRegressor(n_neighbors = 3)
        # regr3 = XGBRegressor()
        # regr4 = SVR(kernel='rbf')
        # regr5 = RandomForestRegressor()
        # # regr6 = MLPRegressor(random_state=1, activation='relu', max_iter=500)
        # regr7 = lgb.LGBMRegressor(boosting_type='gbdt', objective='regression', metric='rmse', 
        #                         num_leaves=31, learning_rate=0.05, feature_fraction=0.9, 
        #                         bagging_fraction=0.8, bagging_freq=5, verbose=-1)

        # # Treinamento dos modelos
        # # regr1.fit(X_train, y_train)
        # # predictions1a = recursive_multistep_forecasting(X_test, regr1, horizon)
        # regr2.fit(X_train, y_train)
        # predictions2a = recursive_multistep_forecasting(X_test, regr2, horizon)
        # regr3.fit(X_train, y_train)
        # predictions3a = recursive_multistep_forecasting(X_test, regr3, horizon)
        # regr4.fit(X_train, y_train)
        # predictions4a = recursive_multistep_forecasting(X_test, regr4, horizon)
        # regr5.fit(X_train, y_train)
        # predictions5a = recursive_multistep_forecasting(X_test, regr5, horizon)
        # # regr6.fit(X_train, y_train)
        # # predictions6a = recursive_multistep_forecasting(X_test, regr6, horizon)
        # regr7.fit(X_train, y_train)
        # predictions7a = recursive_multistep_forecasting(X_test, regr7, horizon)

        # ##########################

        # valores_reais = series.tail(12)
        # valores_reais.reset_index(inplace=True, drop=True)


        # # mape_result1 = mape(valores_reais, predictions1a)
        # mape_result2 = mape(valores_reais, predictions2a)
        # mape_result3 = mape(valores_reais, predictions3a)
        # mape_result4 = mape(valores_reais, predictions4a)
        # mape_result5 = mape(valores_reais, predictions5a)
        # # mape_result6 = mape(valores_reais, predictions6a)
        # mape_result7 = mape(valores_reais, predictions7a)

        # # pbe_result1 = pbe(valores_reais, predictions1a)
        # pbe_result2 = pbe(valores_reais, predictions2a)
        # pbe_result3 = pbe(valores_reais, predictions3a)
        # pbe_result4 = pbe(valores_reais, predictions4a)
        # pbe_result5 = pbe(valores_reais, predictions5a)
        # # pbe_result6 = pbe(valores_reais, predictions6a)
        # pbe_result7 = pbe(valores_reais, predictions7a)

        # # pocid_result1 = pocid(valores_reais, predictions1a)
        # pocid_result2 = pocid(valores_reais, predictions2a)
        # pocid_result3 = pocid(valores_reais, predictions3a)
        # pocid_result4 = pocid(valores_reais, predictions4a)
        # pocid_result5 = pocid(valores_reais, predictions5a)
        # # pocid_result6 = pocid(valores_reais, predictions6a)
        # pocid_result7 = pocid(valores_reais, predictions7a)


        # # Define the folder path
        # folder_path = f"../00-MODELS_UF_MENSAL/"

        # # Create the directory if it doesn't exist
        # os.makedirs(folder_path, exist_ok=True)

        # # p1 = ', '.join(map(str, predictions1a))
        # p2 = ', '.join(map(str, predictions2a))
        # p3 = ', '.join(map(str, predictions3a))
        # p4 = ', '.join(map(str, predictions4a))
        # p5 = ', '.join(map(str, predictions5a))
        # # p6 = ', '.join(map(str, predictions6a))
        # p7 = ', '.join(map(str, predictions7a))

        
        # with open(os.path.join(folder_path, f'{product}_{estado}_KNeighborsRegressor_{features}_{window}_model.pkl'), 'wb') as fd2:
        #     pickle.dump(regr2, fd2)
        
        # with open(os.path.join(folder_path, f'{product}_{estado}_XGBRegressor_{features}_{window}_model.pkl'), 'wb') as fd3:
        #     pickle.dump(regr3, fd3)
        
        # with open(os.path.join(folder_path, f'{product}_{estado}_SVR_{features}_{window}_model.pkl'), 'wb') as fd4:
        #     pickle.dump(regr4, fd4)
        
        # with open(os.path.join(folder_path, f'{product}_{estado}_RandomForestRegressor_{features}_{window}_model.pkl'), 'wb') as fd5:
        #     pickle.dump(regr5, fd5)
        
        # with open(os.path.join(folder_path, f'{product}_{estado}_LGBMRegressor_{features}_{window}_model.pkl'), 'wb') as fd7:
        #     pickle.dump(regr7, fd7)
        
        #     rows_data = [
        #         # [product,estado,'LR',fd1,mape_result1,pocid_result1,pbe_result1,p1],
        #         [product,estado,'kNN',fd2,mape_result2,pocid_result2,pbe_result2,p2],
        #         [product,estado,'XGB',fd3,mape_result3,pocid_result3,pbe_result3,p3],
        #         [product,estado,'SVR',fd4,mape_result4,pocid_result4,pbe_result4,p4],
        #         [product,estado,'RF',fd5,mape_result5,pocid_result5,pbe_result5,p5],
        #         # [product,estado,'MLP',fd6,mape_result6,pocid_result6,pbe_result6,p6],
        #         [product,estado,'LGB',fd7,mape_result7,pocid_result7,pbe_result7,p7]             
        #     ]
        
        
        # # CSV Output VALORES REAIS
        # with open(f'Metrics_{features}_{window}_output.csv', 'a', newline='') as file:
        #     writer = csv.writer(file)
        #     for row_data in rows_data:
        #         writer.writerow(row_data)
# Out:
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.53it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.60it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.99it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.47it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.88it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.77it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.70it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.49it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.70it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.44it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.50it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.47it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.56it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.36it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.71it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.64it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.26it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.54it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.55it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.55it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.79it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.68it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.87it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.97it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.73it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.31it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.29it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.04it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.60it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.43it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.26it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.03it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.61it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.97it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.38it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.69it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.17it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.57it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 22.21it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.89it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.98it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.74it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.76it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.33it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.50it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.12it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.49it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.39it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.46it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.67it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.58it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.27it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.98it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.60it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.96it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.75it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.44it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.41it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.70it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.29it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.20it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.74it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.90it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.87it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.62it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.18it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.19it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.01it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.88it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.33it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.74it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.16it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.74it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.62it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.78it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.43it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.15it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.05it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.89it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.04it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.26it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.96it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.14it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 23.57it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.74it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.87it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.65it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.21it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.65it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.69it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.14it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.86it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 19.27it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.52it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.65it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.94it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.46it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.61it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.53it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.71it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.31it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.52it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.48it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.82it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.60it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.63it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.14it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.04it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.77it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.09it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.27it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.95it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.77it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.66it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.53it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.98it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.85it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.70it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.62it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.41it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.94it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.04it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.50it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 23.35it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.00it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.27it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.85it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.32it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.08it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.49it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 20.28it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.99it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.83it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.67it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.81it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.17it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.39it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.15it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.57it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.08it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.29it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.81it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.99it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.02it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.55it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.17it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.20it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.72it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.96it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.53it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.31it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 24.12it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 24.89it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 22.19it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.76it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.79it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.67it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.17it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.10it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.14it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.26it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.87it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.99it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.22it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.00it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.52it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.38it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.79it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.67it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.28it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.00it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.77it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.84it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.84it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.19it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.53it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.27it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.51it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.90it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.22it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.23it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.81it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.86it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.33it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.87it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.98it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.03it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.52it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.42it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.24it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 23.61it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.76it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.41it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.95it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.26it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.95it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.56it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.09it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.30it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.94it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.55it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.12it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.76it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.14it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.46it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.05it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.44it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.76it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.62it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.63it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.63it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.78it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.85it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.69it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.83it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.13it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.06it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.00it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.18it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.75it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.96it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.44it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.96it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.93it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.42it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.76it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.61it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.02it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.87it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.25it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 22.88it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 24.99it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 18.36it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.31it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.85it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 24.38it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 22.31it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.77it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.99it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.94it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.10it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.14it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.66it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.81it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.74it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.79it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.27it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.94it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.32it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.78it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.50it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.55it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.65it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.51it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.50it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.83it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.22it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.55it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.72it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.32it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.58it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 22.31it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.12it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.24it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.15it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.17it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.58it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.57it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.24it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.50it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.59it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.68it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.86it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.46it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.43it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.45it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.70it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.04it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.62it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.02it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.41it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.53it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.64it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.48it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.80it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.02it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.89it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.90it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.65it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.85it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.81it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.55it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.67it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.08it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.82it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.34it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.49it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.55it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.32it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.51it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.85it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.59it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.74it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.57it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.78it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.92it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.12it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.19it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.80it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.45it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.26it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.48it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.34it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.32it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.36it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 23.87it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.62it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.75it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.13it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.55it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.66it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.79it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.86it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.75it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.50it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.22it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.95it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.99it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.02it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.04it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.77it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.11it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.22it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.38it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.91it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.05it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.86it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.79it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.09it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.61it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.77it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.82it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.47it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.18it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.86it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.28it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.84it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.35it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.57it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.09it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.06it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.63it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.60it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.16it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.69it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.86it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.41it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.15it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.34it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.07it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.76it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.36it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.84it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.32it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.33it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.93it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.99it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.38it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.20it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.37it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.08it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.64it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.24it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.82it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.83it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 22.91it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.22it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.34it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.57it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.42it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.55it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.34it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.54it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.73it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.20it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.15it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.30it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.82it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.11it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.67it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.19it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.30it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.17it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.27it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.15it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.64it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.05it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.14it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.62it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 23.57it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.25it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 22.71it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.53it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.69it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.59it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.36it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.47it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.60it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.51it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.95it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.27it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.67it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.95it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.76it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.67it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.67it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.49it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.20it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.93it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.89it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.82it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.13it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.00it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.12it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.44it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.90it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.47it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.74it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.99it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.25it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.60it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.02it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.08it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.26it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.04it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.58it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.27it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.78it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.93it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.17it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.25it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.85it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.76it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.93it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.50it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.76it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.75it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.53it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.20it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.58it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.63it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.88it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.16it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.14it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.98it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.44it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 23.81it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.26it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.03it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.86it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.07it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.73it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.09it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.30it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.08it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.02it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.19it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.47it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.85it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.61it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.29it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.60it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.42it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.10it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.68it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.56it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.68it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.67it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.52it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.46it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.88it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.22it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.43it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.17it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.57it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.94it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.25it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.72it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.16it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.58it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.48it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.15it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.42it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.36it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.10it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.82it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.69it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.24it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.46it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.49it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.65it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.47it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.55it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.06it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.71it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.36it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.90it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.96it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.77it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 20.37it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.26it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.64it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.27it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.04it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.32it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.37it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.20it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.10it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.86it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.74it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.43it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.62it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.56it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.30it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.53it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.15it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.64it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.17it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.98it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.31it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.75it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.07it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.41it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.16it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.03it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.96it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 23.23it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.24it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.09it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.73it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.35it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.85it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.82it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.87it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.01it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.43it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.71it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.01it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.14it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 24.79it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.22it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.31it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.33it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.03it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.07it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.77it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.62it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.81it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 23.50it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.41it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.86it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.29it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.87it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.68it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 24.14it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.03it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.19it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.94it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.29it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.94it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.65it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.72it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.33it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.57it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.64it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.03it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.66it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.84it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.44it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.69it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.37it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.25it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.32it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.70it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.58it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.86it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.67it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.49it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.81it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.15it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.27it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.08it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.10it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 22.04it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.06it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.00it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.30it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.51it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.63it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.04it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.74it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.65it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.98it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 24.52it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 23.31it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.67it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.12it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.43it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.77it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.54it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.46it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.47it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.30it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.27it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.56it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.39it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.77it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.45it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.70it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.36it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.98it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.89it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.22it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.90it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 21.79it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.78it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.13it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.11it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.61it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.22it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.73it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.41it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.58it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.56it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.74it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.43it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.55it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.63it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.81it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.89it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.91it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.59it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.23it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.74it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.70it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.00it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.35it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.46it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.53it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.55it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.38it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.21it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.84it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.54it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.24it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.89it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.86it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.12it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.08it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.82it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.11it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.07it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.51it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.89it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.88it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.00it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.61it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.38it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.96it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.02it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.12it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.99it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.86it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.16it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.59it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.36it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.48it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 19.37it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.77it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.09it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.22it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.27it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.06it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.55it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.17it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 22.15it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.35it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.72it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.18it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.33it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.56it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.37it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.86it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.30it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.43it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.00it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 23.25it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.62it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.92it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.52it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.42it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.69it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.85it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.93it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.90it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.55it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.35it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.94it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.48it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.50it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.02it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.20it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.95it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.91it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.77it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.34it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 23.70it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.84it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.79it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.40it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.53it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.42it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.28it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.40it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.13it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.33it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.54it/s]
# ...
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.02it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.67it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.57it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.26it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.08it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.36it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.32it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.49it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.53it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.50it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.81it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.54it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.66it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.78it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.84it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.79it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.03it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.22it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.23it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.15it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.91it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.58it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.20it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.67it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.69it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.94it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.68it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.63it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.34it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.82it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.96it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.47it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.43it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.65it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.48it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.28it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.69it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.25it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.75it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 24.28it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.77it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.18it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.49it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.04it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.72it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.15it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.80it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.69it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.65it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.56it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.80it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 24.58it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.67it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.84it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.66it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.34it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.33it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.88it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.19it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.15it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.76it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.40it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.66it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.83it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.80it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.52it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.12it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.84it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.30it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.22it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.95it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.95it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.86it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.52it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.56it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.70it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.08it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.43it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.49it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.32it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.52it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.64it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.82it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.09it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.73it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.57it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.67it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.28it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.14it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.02it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.44it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.11it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.53it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.41it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.31it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.47it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.76it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.78it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.87it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 24.71it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.30it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.81it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.73it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.52it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.92it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.73it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.62it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.80it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.05it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.36it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.53it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.40it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.05it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.59it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.73it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.84it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.64it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 23.65it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.65it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.66it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.50it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.93it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.67it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.48it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.72it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.04it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.74it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.78it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.92it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.16it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.69it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.07it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.05it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.24it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.32it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.84it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.24it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 25.79it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.22it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.91it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.48it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.40it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.43it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.57it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.12it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.30it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.33it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.64it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.90it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.13it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.22it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.72it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.66it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.41it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.86it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.33it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.13it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.84it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.62it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.80it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.55it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.32it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.63it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.54it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.41it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.17it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.48it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.08it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.53it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.03it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.67it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.53it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.16it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.03it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.82it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.83it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.26it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.47it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.67it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.64it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.58it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.69it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.32it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.57it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.97it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.78it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.68it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.78it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.57it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.46it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.63it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.10it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.97it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.76it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.70it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.77it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.24it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.34it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.78it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 24.07it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.58it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.45it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.81it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.72it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.64it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.57it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.96it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.69it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.03it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.75it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.66it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.36it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.58it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 26.92it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.80it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.60it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.52it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.28it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.45it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.25it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 27.22it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.27it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.25it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.79it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.97it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.72it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.43it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.36it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.66it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.80it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.91it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.83it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.67it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.80it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.51it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.78it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 31.53it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.01it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 28.99it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.67it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 30.71it/s]
# Feature Extraction: 100%|██████████| 1/1 [00:00<00:00, 29.55it/s]
